# %%
import pandas  as pd
import numpy  as np
import matplotlib.pyplot as plt
from   pylab  import  *
# Out:
# /srv/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /srv/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df=pd.DataFrame(np.random.randn(10,4),columns=list('ABCD'))#10行4列正态分布随机数

# %%
df
# Out:
#           A         B         C         D
# 0  0.740239 -0.631965 -0.502665 -0.139280
# 1  0.924817 -0.666057  1.538949  0.765976
# 2  1.531487 -0.830476  0.601341 -0.107854
# 3  2.020644  0.434380  0.799315 -0.065502
# 4 -0.522532  0.759805  0.921367 -1.533412
# 5  0.902702  2.033236  0.012654  0.175560
# 6  0.152406  0.773586  0.437420 -0.764101
# 7 -1.549277 -2.449481  1.786529 -0.163831
# 8 -0.223348 -1.906067  1.216778  0.200465
# 9 -0.558460  0.831279  1.761092 -1.004076

# %%
df.plot(figsize=(24,4))

# %%
df=df.cumsum(0)#按行累加

# %%
df
# Out:
#           A         B         C         D
# 0  0.740239 -0.631965 -0.502665 -0.139280
# 1  1.665056 -1.298023  1.036284  0.626696
# 2  3.196543 -2.128499  1.637625  0.518842
# 3  5.217187 -1.694119  2.436940  0.453339
# 4  4.694655 -0.934314  3.358307 -1.080072
# 5  5.597357  1.098923  3.370960 -0.904512
# 6  5.749763  1.872509  3.808380 -1.668613
# 7  4.200486 -0.576972  5.594909 -1.832444
# 8  3.977139 -2.483039  6.811687 -1.631979
# 9  3.418679 -1.651760  8.572780 -2.636055

# %%
df.plot(figsize=(24,4))

# %%
#创建一个画布对象。一个画布可以有多幅子图。
fig=plt.figure(figsize=(24,4), dpi=80)

#在画布中创建一个子图，指定一行、一列的第一幅。
p1=fig.add_subplot(1,1,1)

#绘制第一条曲线。
p1.plot(df.index,df['A'])
p1.plot(df.index,df['B'])
p1.plot(df.index,df['C'])
p1.plot(df.index,df['D'])

#显示图形。
plt.show()

# %%
df=df.cumsum()#按行累加

# %%
df
# Out:
#            A         B          C         D
# 0   0.740239 -0.631965  -0.502665 -0.139280
# 1   2.405295 -1.929988   0.533619  0.487416
# 2   5.601838 -4.058487   2.171244  1.006258
# 3  10.819025 -5.752606   4.608183  1.459597
# 4  15.513679 -6.686919   7.966490  0.379525
# 5  21.111036 -5.587997  11.337450 -0.524987
# 6  26.860799 -3.715488  15.145830 -2.193600
# 7  31.061286 -4.292460  20.740739 -4.026044
# 8  35.038424 -6.775499  27.552427 -5.658023
# 9  38.457103 -8.427258  36.125206 -8.294078

# %%
df=pd.DataFrame(np.random.randn(10,4),columns=list('ABCD'))#10行4列正态分布随机数

# %%
df
# Out:
#           A         B         C         D
# 0 -0.650609  1.168758 -1.187868 -0.925324
# 1  0.272831  0.735223 -0.907888 -0.842921
# 2 -0.193199  1.286445  0.333305 -0.127900
# 3 -0.012916  1.399679  2.163607  0.526716
# 4  0.286731 -0.840734  0.426420 -0.670532
# 5 -0.915882 -0.043608  1.169407 -1.013205
# 6  0.785284  1.226851 -1.383284  0.639724
# 7 -0.960526 -0.001745 -0.278436  0.324856
# 8 -1.619125 -0.696559  2.066422  0.528117
# 9 -0.524511 -0.386747  1.235890  0.222814

# %%
df=df.cumsum(1)#按列累加

# %%
df
# Out:
#           A         B         C         D
# 0 -0.650609  0.518149 -0.669718 -1.595043
# 1 -0.377778  1.526202 -0.569553 -2.337799
# 2 -0.570977  2.619449  0.856998 -1.039148
# 3 -0.583893  4.006211  4.407367  3.037938
# 4 -0.297162  3.452208  4.279785  2.239824
# 5 -1.213044  2.492718  4.489702  1.436535
# 6 -0.427761  4.504853  5.118553  2.705110
# 7 -1.388287  3.542581  3.877845  1.789258
# 8 -3.007412  1.226897  3.628584  2.068113
# 9 -3.531923  0.315639  3.953216  2.615560

# %%
df=df.cumsum()#按列累加

# %%
df
# Out:
#            A          B          C          D
# 0  -0.650609   0.518149  -0.669718  -1.595043
# 1  -1.028386   2.044352  -1.239272  -3.932841
# 2  -1.599363   4.663800  -0.382273  -4.971989
# 3  -2.183256   8.670011   4.025094  -1.934051
# 4  -2.480418  12.122219   8.304879   0.305773
# 5  -3.693463  14.614937  12.794581   1.742308
# 6  -4.121224  19.119789  17.913133   4.447417
# 7  -5.509511  22.662370  21.790979   6.236675
# 8  -8.516923  23.889267  25.419562   8.304788
# 9 -12.048846  24.204906  29.372778  10.920348

# %%
df.plot(figsize=(24,4))

# %%
#散点图-标准正态分布,以0为中心，1为标准差，1024个点
n = 1024
X = np.random.normal(0,1,n)#产生数
Y = np.random.normal(0,1,n)
scatter(X,Y)
show()

# %%
# 画简单的图形，
x=np.linspace(-np.pi,np.pi,256,endpoint=True)#从负pi到正pi,256个数;在指定的间隔内返回均匀间隔的数字
c,s=np.cos(x),np.sin(x)
plot(x,c, color="blue", linewidth=2.5, linestyle="-", label="cosine")  #label用于标签显示问题
plot(x,s,color="red",  linewidth=5.5, linestyle="-", label="sine")
show()

# %%
# 画简单的图形，
x=np.linspace(-np.pi,np.pi,256,endpoint=True)#从负pi到正pi,必须是256个数;在指定的间隔内返回均匀间隔的数字
c,s=np.cos(x),np.sin(x)

plot(x,c, color="r", linewidth=2.5, linestyle="-", label="cosine")  #label用于标签显示问题;x轴是x,y轴是c，颜色，线宽，线型
plot(x,s,color="g",  linewidth=2.5, linestyle="-", label="sine")
show()

# %%
# 画简单的图形，
x=np.linspace(-np.pi,np.pi,256,endpoint=True)#从负pi到正pi,必须是256个数;在指定的间隔内返回均匀间隔的数字
c,s=np.cos(x),np.sin(x)

plot(x,c, linewidth=2.5, linestyle="-", label="cosine")  #label用于标签显示问题;x轴是x,y轴是c，颜色，线宽，线型
plot(x,s,  linewidth=2.5, linestyle="-", label="sine")
show()

# %%
#条形图
n = 12
X = np.arange(n)#一个有终点和起点的固定步长的排列,参数值为终点，起点取默认值0，步长取默认值1。
Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)#numpy.random.uniform(low,high,size),从一个均匀分布[low,high)中随机采样，注意定义域是左闭右开，即包含low，不包含high
#low: 采样下界，float类型，默认值为0；high: 采样上界，float类型，默认值为1；size: 输出样本数目，为int或元组(tuple)类型，例如，size=(m,n,k), 则输出m*n*k个样本，缺省时输出1个值。
Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
bar(X, -Y2, facecolor='#ff9999', edgecolor='white')
for x,y in zip(X,Y1):
    text(x+0.4, y+0.05, '%.2f' % y, ha='center', va= 'bottom')
ylim(-1.25,+1.25)
show()

# %%
ts=pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000',periods=1000))
ts=ts.cumsum()
ts.plot()
plt.show()

# %%
df=pd.DataFrame(np.random.randn(1000,4),index=ts.index,columns=list('ABCD'))
df=df.cumsum()
df.plot()
plt.show()

# %%
#画柱状图
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot(kind='bar')  #分开并列线束
df2.plot(kind='bar', stacked=True) #四个在同一个里面显示 百分比的形式
df2.plot(kind='barh', stacked=True)#纵向显示
plt.show()

# %%
df4=pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':np.random.randn(1000)-1},columns=list('abc'))
df4.plot(kind='hist', alpha=0.5)
df4.plot(kind='hist', stacked=True, bins=20)
df4['a'].plot(kind='hist', orientation='horizontal',cumulative=True) #cumulative是按顺序排序，加上这个
plt.show()

# %%
#Area Plot
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot(kind='area')
df.plot(kind='area',stacked=False)
plt.show()
